# %% [markdown]
# # Imports

# %%
# from sklearnex import patch_sklearn
# patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
import numpy as np
import polars as pl
import re

from embedding_model import EmbeddingModel

# %% [markdown]
# # Functions Definition

# %%
def textPreprocessing(text: str):
    if text is not None:
        text = text.lower()
        text = text.strip()
        text = re.sub(r'\d+', r' ', text)
        text = re.sub(r'[!@#$%^&*()_+\-=\[\]{};\'\\:"|,.<>\/?]', r'', text)
        text = re.sub(r'\b[a-zÀ-ÖØ-öø-ÿ]{1,2}\b', r' ', text)
        text = re.sub(r'\s+', r' ', text)
    return text

def averagePooling(embeddings: np.ndarray) -> np.ndarray:
    return sum(embeddings) / len(embeddings)

# %% [markdown]
# # Process Definition

# %% [markdown]
# ## Query database (deprecated)

# %%
con_string = 'postgresql://postgres:postgres@localhost/ituassu_2022'
query = "select id, content_text from x_content xc"

# %%
df = pl.read_database_uri(query, con_string, partition_num=5120)
df
# Out:
# shape: (57_925_235, 2)
# ┌─────────────────────┬───────────────────────────────────┐
# │ id                  ┆ content_text                      │
# │ ---                 ┆ ---                               │
# │ str                 ┆ str                               │
# ╞═════════════════════╪═══════════════════════════════════╡
# │ 1577355341716676609 ┆ RT @alteddy_: BRASIL GANHANDO DA… │
# │ 1577355048883220480 ┆ BRASIL GANHANDO DA ITÁLIA, TRAGA… │
# │ 1577355341607874560 ┆ RT @siteptbr: 🚨 Em pleno         │
# │                     ┆ Outubro…                          │
# │ 1577317662123642880 ┆ 🚨 Em pleno Outubro Rosa,         │
# │                     ┆ Governo…                          │
# │ 1577355341406289920 ┆ RT @onlybluestyles: Deus abençoe… │
# │ …                   ┆ …                                 │
# │ 1586553559495200769 ┆ RT @joelspunk: lula ganhe por fa… │
# │ 1586553522807513088 ┆ RT @vinicomentx: Desmentindo men… │
# │ 1586553516839018499 ┆ Lula eh hoje                      │
# │ 1586553514016342016 ┆ RT @choquei: 🚨AGORA: Com a voz   │
# │                     ┆ d…                                │
# │ 1586553508521811970 ┆ RT @pablovillaca: Vamos deixar c… │
# └─────────────────────┴───────────────────────────────────┘

# %% [markdown]
# ## Prepare embedding model

# %%
embedding_model = EmbeddingModel(256)
# Out:
# f:\anaconda3\envs\mestrado\Lib\site-packages\torch\_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %% [markdown]
# ## Importing data

# %%
# q1 = (
#     pl.scan_csv('tweets.csv', separator=';', low_memory=True).lazy().with_columns(
#         pl.col("content_text").map_elements(textPreprocessing).alias('processed_text')
#     ).with_columns(
#         pl.col("processed_text").map_batches(lambda series: embedding_model.get_embeddings(series, 32768)).alias('embeddings')
#     )
# )
# df = q1.collect(streaming=True)
# Out:
# Creating data loaders
# Generating embeddings
# Process Time (sec): 1550.351292499996

# %%
lazy_df = pl.scan_csv('tweets.csv', separator=';', low_memory=True)

# %%
lazy_df.lazy().count().collect()
# Out:
# shape: (1, 4)
# ┌──────────┬──────────────┬────────────┬──────────────┐
# │ id       ┆ content_text ┆ created_at ┆ fk_author_id │
# │ ---      ┆ ---          ┆ ---        ┆ ---          │
# │ u32      ┆ u32          ┆ u32        ┆ u32          │
# ╞══════════╪══════════════╪════════════╪══════════════╡
# │ 57925235 ┆ 57925235     ┆ 57925235   ┆ 57925235     │
# └──────────┴──────────────┴────────────┴──────────────┘

# %% [markdown]
# ## Preprocessing the text

# %%
query1 = (
    lazy_df.lazy().with_columns(
        pl.col("content_text").map_elements(textPreprocessing).alias('processed_text')
    ).select(pl.col("id"), pl.col("processed_text"))
)
lazy_df = query1.collect()

# %%
lazy_df.lazy().count().collect()
# Out:
# shape: (1, 2)
# ┌──────────┬────────────────┐
# │ id       ┆ processed_text │
# │ ---      ┆ ---            │
# │ u32      ┆ u32            │
# ╞══════════╪════════════════╡
# │ 57925235 ┆ 57925235       │
# └──────────┴────────────────┘

# %% [markdown]
# ## Converting to embeddings

# %%
query2 = (
    lazy_df.lazy().with_columns(
        pl.col("processed_text").map_batches(lambda series: embedding_model.get_embeddings(series, 24576)).alias('embeddings')
    )
)
lazy_df = query2.collect()
# Out:
# Creating data loaders
# Generating embeddings
# Embeddings for 0 of 2357 data loaders
# x_train_bt conversion to list: 0.0002051999999821419
# move input to gpu: 4.864922000000661
# calculate embeddings: 0.03483760000017355
# add embeddings to list: 4.0582211000000825
# Embeddings for 1 of 2357 data loaders
# x_train_bt conversion to list: 0.0001940000001923181
# move input to gpu: 3.2938433999988774
# calculate embeddings: 5.421931900000345
# add embeddings to list: 2.5157604000014544
# Embeddings for 2 of 2357 data loaders
# x_train_bt conversion to list: 0.00017809999917517416
# move input to gpu: 2.426744800000961
# calculate embeddings: 0.0003395000003365567
# add embeddings to list: 3.5858381999987614
# Embeddings for 3 of 2357 data loaders
# x_train_bt conversion to list: 0.0001818999990064185
# move input to gpu: 2.438289399999121
# calculate embeddings: 0.000380000001314329
# add embeddings to list: 1.598999300000287
# Embeddings for 4 of 2357 data loaders
# x_train_bt conversion to list: 0.00023330000112764537
# move input to gpu: 3.2969110000012734
# calculate embeddings: 0.00037339999835239723
# add embeddings to list: 3.172793699999602
# Embeddings for 5 of 2357 data loaders
# x_train_bt conversion to list: 0.0001931000006152317
# move input to gpu: 3.3265154999990045
# calculate embeddings: 0.000389000000723172
# add embeddings to list: 0.7942977000002429
# Embeddings for 6 of 2357 data loaders
# x_train_bt conversion to list: 0.00017490000027464703
# move input to gpu: 2.388797900001009
# calculate embeddings: 0.0004141000008530682
# add embeddings to list: 3.216458099999727
# Embeddings for 7 of 2357 data loaders
# x_train_bt conversion to list: 0.00018230000023322646
# move input to gpu: 2.410945999999967
# calculate embeddings: 0.0004589000000123633
# add embeddings to list: 1.6008555999997043
# Embeddings for 8 of 2357 data loaders
# x_train_bt conversion to list: 0.00018679999993764795
# move input to gpu: 2.4221708999994007
# calculate embeddings: 0.0004405999989103293
# add embeddings to list: 4.0437925000005635
# Embeddings for 9 of 2357 data loaders
# x_train_bt conversion to list: 0.00019460000112303533
# move input to gpu: 2.4133999999994558
# calculate embeddings: 0.0004073000000062166
# add embeddings to list: 0.734746100000848
# Embeddings for 10 of 2357 data loaders
# x_train_bt conversion to list: 0.0001833000005717622
# move input to gpu: 3.291737199999261
# calculate embeddings: 0.00043700000060198363
# add embeddings to list: 3.1604434000000765
# Embeddings for 11 of 2357 data loaders
# x_train_bt conversion to list: 0.0004935999986628303
# move input to gpu: 3.267817500000092
# calculate embeddings: 0.0004864999991696095
# add embeddings to list: 0.6993624000006093
# Embeddings for 12 of 2357 data loaders
# x_train_bt conversion to list: 0.00018290000116394367
# move input to gpu: 2.424790600000051
# calculate embeddings: 0.00051059999896097
# add embeddings to list: 4.00823390000005
# Embeddings for 13 of 2357 data loaders
# x_train_bt conversion to list: 0.00030610000067099463
# move input to gpu: 2.411360899999636
# calculate embeddings: 0.0004958999998052604
# add embeddings to list: 0.7618352999998024
# Embeddings for 14 of 2357 data loaders
# x_train_bt conversion to list: 0.00017830000069807284
# move input to gpu: 3.2956314999992173
# calculate embeddings: 0.00050809999993362
# add embeddings to list: 3.1476468999990175
# Embeddings for 15 of 2357 data loaders
# x_train_bt conversion to list: 0.0003281999997852836
# move input to gpu: 2.408325300000797
# calculate embeddings: 0.000672399999530171
# add embeddings to list: 1.5236394000003202
# Embeddings for 16 of 2357 data loaders
# x_train_bt conversion to list: 0.00019439999960013665
# move input to gpu: 2.421790399999736
# calculate embeddings: 0.0006415000007109484
# add embeddings to list: 3.160364199999094
# Embeddings for 17 of 2357 data loaders
# x_train_bt conversion to list: 0.00019950000023527537
# move input to gpu: 3.3143041000002995
# calculate embeddings: 0.0005324000012478791
# add embeddings to list: 0.7201136000003316
# Embeddings for 18 of 2357 data loaders
# x_train_bt conversion to list: 0.00020589999985531904
# move input to gpu: 2.42393439999978
# calculate embeddings: 0.0005335999994713347
# add embeddings to list: 3.2080388000013045
# Embeddings for 19 of 2357 data loaders
# x_train_bt conversion to list: 0.00019500000053085387
# move input to gpu: 2.423273299998982
# calculate embeddings: 0.0007045000002108281
# add embeddings to list: 0.7969168999989051
# Embeddings for 20 of 2357 data loaders
# x_train_bt conversion to list: 0.00019330000031914096
# move input to gpu: 3.3076884000001883
# calculate embeddings: 0.0004607999999279855
# add embeddings to list: 3.16563270000006
# Embeddings for 21 of 2357 data loaders
# x_train_bt conversion to list: 0.00020170000061625615
# move input to gpu: 2.43401300000005
# calculate embeddings: 0.0005544999985431787
# add embeddings to list: 0.7195327000008547
# Embeddings for 22 of 2357 data loaders
# x_train_bt conversion to list: 0.0001905999997688923
# move input to gpu: 3.302118800000244
# calculate embeddings: 0.00047110000014072284
# add embeddings to list: 3.164545800000269
# Embeddings for 23 of 2357 data loaders
# x_train_bt conversion to list: 0.00019910000082745682
# move input to gpu: 2.4153408000001946
# calculate embeddings: 0.0005234000000200467
# add embeddings to list: 0.7466882999997324
# Embeddings for 24 of 2357 data loaders
# x_train_bt conversion to list: 0.00020629999926313758
# move input to gpu: 3.3367008000004716
# calculate embeddings: 0.0006587999996554572
# add embeddings to list: 3.2175647000003664
# Embeddings for 25 of 2357 data loaders
# x_train_bt conversion to list: 0.00032730000020819716
# move input to gpu: 2.473842600000353
# calculate embeddings: 0.0005180999996809987
# add embeddings to list: 0.732886800000415
# Embeddings for 26 of 2357 data loaders
# x_train_bt conversion to list: 0.00019559999964258168
# move input to gpu: 3.3263210999994044
# calculate embeddings: 0.0005655000004480826
# add embeddings to list: 3.1677939999990485
# Embeddings for 27 of 2357 data loaders
# x_train_bt conversion to list: 0.00020489999951678328
# move input to gpu: 2.4388586999994004
# calculate embeddings: 0.0005027000006521121
# add embeddings to list: 0.7163762000000133
# Embeddings for 28 of 2357 data loaders
# x_train_bt conversion to list: 0.00022329999956127722
# move input to gpu: 3.309595500000796
# calculate embeddings: 0.0005085000011604279
# add embeddings to list: 3.1459224999998696
# Embeddings for 29 of 2357 data loaders
# x_train_bt conversion to list: 0.000198199999431381
# move input to gpu: 2.4181110999998054
# calculate embeddings: 0.0005994000002829125
# add embeddings to list: 0.7389263000004576
# Embeddings for 30 of 2357 data loaders
# x_train_bt conversion to list: 0.00019640000027720816
# move input to gpu: 2.427060600000914
# calculate embeddings: 0.0006463999998231884
# add embeddings to list: 3.2235046999994665
# Embeddings for 31 of 2357 data loaders
# x_train_bt conversion to list: 0.00020399999993969686
# move input to gpu: 2.4355341000009503
# calculate embeddings: 0.000568899999052519
# add embeddings to list: 0.7300562000000355
# Embeddings for 32 of 2357 data loaders
# x_train_bt conversion to list: 0.0002030000014201505
# move input to gpu: 2.4410464000011416
# calculate embeddings: 0.0006809999995311955
# add embeddings to list: 4.033369400000083
# Embeddings for 33 of 2357 data loaders
# x_train_bt conversion to list: 0.00021100000049045775
# move input to gpu: 2.451373500000045
# calculate embeddings: 0.0006216000001586508
# add embeddings to list: 0.7621128000009776
# Embeddings for 34 of 2357 data loaders
# x_train_bt conversion to list: 0.0001990000000660075
# move input to gpu: 2.432346999999936
# calculate embeddings: 0.0005846000003657537
# add embeddings to list: 3.160551299999497
# Embeddings for 35 of 2357 data loaders
# x_train_bt conversion to list: 0.00021099999867146835
# move input to gpu: 3.386447599999883
# calculate embeddings: 0.0007828999987395946
# add embeddings to list: 0.7288308999995934
# Embeddings for 36 of 2357 data loaders
# x_train_bt conversion to list: 0.00022030000036465935
# move input to gpu: 2.441962400000193
# calculate embeddings: 0.0006295000002864981
# add embeddings to list: 3.178341200000432
# Embeddings for 37 of 2357 data loaders
# x_train_bt conversion to list: 0.00027099999897473026
# move input to gpu: 2.4216167999984464
# calculate embeddings: 0.0010734000006777933
# add embeddings to list: 0.7506436999992729
# Embeddings for 38 of 2357 data loaders
# x_train_bt conversion to list: 0.00021379999998316634
# move input to gpu: 3.4085068000003957
# calculate embeddings: 0.00090979999913543
# add embeddings to list: 3.165655799999513
# Embeddings for 39 of 2357 data loaders
# x_train_bt conversion to list: 0.0003547000014805235
# move input to gpu: 2.4564471999983652
# calculate embeddings: 0.001645000000280561
# add embeddings to list: 0.7257410999991407
# Embeddings for 40 of 2357 data loaders
# x_train_bt conversion to list: 0.00021939999714959413
# move input to gpu: 2.460783900001843
# calculate embeddings: 0.0009744000017235521
# add embeddings to list: 3.2236116000021866
# Embeddings for 41 of 2357 data loaders
# x_train_bt conversion to list: 0.0003209999995306134
# move input to gpu: 2.4492694000000483
# calculate embeddings: 0.0008669000017107464
# add embeddings to list: 0.7320987999992212
# Embeddings for 42 of 2357 data loaders
# x_train_bt conversion to list: 0.00020940000104019418
# move input to gpu: 2.4452600000004168
# calculate embeddings: 0.0006166999992274214
# add embeddings to list: 3.1641457000005175
# Embeddings for 43 of 2357 data loaders
# x_train_bt conversion to list: 0.00022340000214171596
# move input to gpu: 3.4586946000017633
# calculate embeddings: 0.0008959000006143469
# add embeddings to list: 0.6909723999997368
# Embeddings for 44 of 2357 data loaders
# x_train_bt conversion to list: 0.0002238000015495345
# move input to gpu: 2.451916899997741
# calculate embeddings: 0.00047959999938029796
# add embeddings to list: 3.1540854000013496
# Embeddings for 45 of 2357 data loaders
# x_train_bt conversion to list: 0.00021770000239484943
# move input to gpu: 2.446686999999656
# calculate embeddings: 0.0006151999987196177
# add embeddings to list: 0.7540503999989596
# Embeddings for 46 of 2357 data loaders
# x_train_bt conversion to list: 0.00020980000044801272
# move input to gpu: 2.585622599999624
# calculate embeddings: 0.0006339000028674491
# add embeddings to list: 3.2267156000016257
# Embeddings for 47 of 2357 data loaders
# x_train_bt conversion to list: 0.0002285999980813358
# move input to gpu: 2.4555567000024894
# calculate embeddings: 0.0005756999998993706
# add embeddings to list: 0.7610502999996243
# Embeddings for 48 of 2357 data loaders
# x_train_bt conversion to list: 0.0002117000003636349
# move input to gpu: 2.4664449999982025
# calculate embeddings: 0.0008264999996754341
# add embeddings to list: 3.1559599000029266
# Embeddings for 49 of 2357 data loaders
# x_train_bt conversion to list: 0.00020279999807826243
# move input to gpu: 2.5680427000006603
# calculate embeddings: 0.0009070000014617108
# add embeddings to list: 1.6709540999981982
# Embeddings for 50 of 2357 data loaders
# x_train_bt conversion to list: 0.0001914000022225082
# move input to gpu: 2.4348288999972283
# calculate embeddings: 0.000885600002220599
# add embeddings to list: 3.1503219999976864
# Embeddings for 51 of 2357 data loaders
# x_train_bt conversion to list: 0.00022560000070370734
# move input to gpu: 2.43353389999902
# calculate embeddings: 0.0006300999993982259
# add embeddings to list: 0.7177707000009832
# Embeddings for 52 of 2357 data loaders
# x_train_bt conversion to list: 0.00022519999765791
# move input to gpu: 2.4753688999990118
# calculate embeddings: 0.0008425999985774979
# add embeddings to list: 3.179328899997927
# Embeddings for 53 of 2357 data loaders
# x_train_bt conversion to list: 0.0002122999976563733
# move input to gpu: 3.485326599999098
# calculate embeddings: 0.0008381000006920658
# add embeddings to list: 0.6977713000014774
# Embeddings for 54 of 2357 data loaders
# x_train_bt conversion to list: 0.0002151000007870607
# move input to gpu: 2.6078632999997353
# calculate embeddings: 0.0007108999998308718
# add embeddings to list: 3.16543079999974
# Embeddings for 55 of 2357 data loaders
# x_train_bt conversion to list: 0.0002392999995208811
# move input to gpu: 2.4183716000006825
# calculate embeddings: 0.0006539999994856771
# add embeddings to list: 0.7272456999999122
# Embeddings for 56 of 2357 data loaders
# x_train_bt conversion to list: 0.00021129999731783755
# move input to gpu: 3.487816200002271
# calculate embeddings: 0.0011900999998033512
# add embeddings to list: 3.1468700999976136
# Embeddings for 57 of 2357 data loaders
# x_train_bt conversion to list: 0.00021710000146413222
# move input to gpu: 2.575946799999656
# calculate embeddings: 0.0007749000033072662
# add embeddings to list: 0.7203402000013739
# Embeddings for 58 of 2357 data loaders
# x_train_bt conversion to list: 0.00021399999968707561
# move input to gpu: 2.499006600002758
# calculate embeddings: 0.000647100001515355
# add embeddings to list: 3.192685899997741
# Embeddings for 59 of 2357 data loaders
# x_train_bt conversion to list: 0.00021520000154851004
# move input to gpu: 2.562600700002804
# calculate embeddings: 0.0005353999986255076
# add embeddings to list: 0.684273499999108
# Embeddings for 60 of 2357 data loaders
# x_train_bt conversion to list: 0.0002201000024797395
# move input to gpu: 3.4538107000007585
# calculate embeddings: 0.0005458999985421542
# add embeddings to list: 3.1492919999982405
# Embeddings for 61 of 2357 data loaders
# x_train_bt conversion to list: 0.00021700000070268288
# move input to gpu: 2.4242561999999452
# calculate embeddings: 0.0008791000000201166
# add embeddings to list: 0.7277233000022534
# Embeddings for 62 of 2357 data loaders
# x_train_bt conversion to list: 0.000207500001124572
# move input to gpu: 2.4310433999999077
# calculate embeddings: 0.0007101000010152347
# add embeddings to list: 3.1328699000005145
# Embeddings for 63 of 2357 data loaders
# x_train_bt conversion to list: 0.0002113999980792869
# move input to gpu: 2.532583500000328
# calculate embeddings: 0.0008086000016191974
# add embeddings to list: 0.7163483000003907
# Embeddings for 64 of 2357 data loaders
# x_train_bt conversion to list: 0.00021010000273236074
# move input to gpu: 3.3665699000011955
# calculate embeddings: 0.00089990000196849
# add embeddings to list: 3.152545500000997
# Embeddings for 65 of 2357 data loaders
# x_train_bt conversion to list: 0.00021470000137924217
# move input to gpu: 2.3953318999992916
# calculate embeddings: 0.0006428000015148427
# add embeddings to list: 0.6934707999971579
# Embeddings for 66 of 2357 data loaders
# x_train_bt conversion to list: 0.00021699999706470408
# move input to gpu: 2.535424599998805
# calculate embeddings: 0.0005679999994754326
# add embeddings to list: 3.158555300000444
# Embeddings for 67 of 2357 data loaders
# x_train_bt conversion to list: 0.00022449999960372224
# move input to gpu: 2.4138329999987036
# calculate embeddings: 0.0005448999982036185
# add embeddings to list: 0.6814097999995283
# Embeddings for 68 of 2357 data loaders
# x_train_bt conversion to list: 0.00020360000053187832
# move input to gpu: 3.3624333000007027
# calculate embeddings: 0.0007136000022001099
# add embeddings to list: 3.129364699998405
# Embeddings for 69 of 2357 data loaders
# x_train_bt conversion to list: 0.00030759999935980886
# move input to gpu: 2.418135699997947
# calculate embeddings: 0.0007160000022849999
# add embeddings to list: 0.683565000003
# Embeddings for 70 of 2357 data loaders
# x_train_bt conversion to list: 0.00026479999723960645
# move input to gpu: 2.4120766000014555
# calculate embeddings: 0.0006556999978784006
# add embeddings to list: 3.148191300002509
# Embeddings for 71 of 2357 data loaders
# x_train_bt conversion to list: 0.0002237999979115557
# move input to gpu: 2.441196300002048
# calculate embeddings: 0.0005524000007426366
# add embeddings to list: 0.7081735000028857
# Embeddings for 72 of 2357 data loaders
# x_train_bt conversion to list: 0.0002027000009547919
# move input to gpu: 2.3985113999988243
# calculate embeddings: 0.0005743999972764868
# add embeddings to list: 3.1991264000025694
# Embeddings for 73 of 2357 data loaders
# x_train_bt conversion to list: 0.00022519999765791
# move input to gpu: 2.5423570000020845
# calculate embeddings: 0.000590899999224348
# add embeddings to list: 0.6981804999995802
# Embeddings for 74 of 2357 data loaders
# x_train_bt conversion to list: 0.00022030000036465935
# move input to gpu: 2.4454939999995986
# calculate embeddings: 0.000590899999224348
# add embeddings to list: 3.127968699998746
# Embeddings for 75 of 2357 data loaders
# x_train_bt conversion to list: 0.000700400003552204
# move input to gpu: 2.5821722999971826
# calculate embeddings: 0.0007627999984833878
# add embeddings to list: 0.6929701000008208
# Embeddings for 76 of 2357 data loaders
# x_train_bt conversion to list: 0.00022109999918029644
# move input to gpu: 2.5518206999986432
# calculate embeddings: 0.0009580000005371403
# add embeddings to list: 3.290123599999788
# Embeddings for 77 of 2357 data loaders
# x_train_bt conversion to list: 0.00024869999833754264
# move input to gpu: 6.088668600001256
# calculate embeddings: 0.0013963999990664888
# add embeddings to list: 1.2524797999976727
# Embeddings for 78 of 2357 data loaders
# x_train_bt conversion to list: 0.0002303000001120381
# move input to gpu: 4.493834299999435
# calculate embeddings: 0.0008973000003607012
# add embeddings to list: 3.271038099999714
# Embeddings for 79 of 2357 data loaders
# x_train_bt conversion to list: 0.00019529999917722307
# move input to gpu: 4.340587700000469
# calculate embeddings: 0.0003758999991987366
# add embeddings to list: 1.2963429000010365
# Embeddings for 80 of 2357 data loaders
# x_train_bt conversion to list: 0.00018959999943035655
# move input to gpu: 4.63398529999904
# calculate embeddings: 0.0009867999979178421
# add embeddings to list: 3.2338319000009506
# Embeddings for 81 of 2357 data loaders
# x_train_bt conversion to list: 0.00019579999934649095
# move input to gpu: 4.681801999999152
# calculate embeddings: 0.00014929999815649353
# add embeddings to list: 3.53916830000162
# Embeddings for 82 of 2357 data loaders
# x_train_bt conversion to list: 0.00019560000146157108
# move input to gpu: 4.762899500001367
# calculate embeddings: 0.0010108000024047215
# add embeddings to list: 3.322508099998231
# Embeddings for 83 of 2357 data loaders
# x_train_bt conversion to list: 0.00026250000155414455
# move input to gpu: 4.69194570000036
# calculate embeddings: 0.00045680000039283186
# add embeddings to list: 1.5303981000033673
# Embeddings for 84 of 2357 data loaders
# x_train_bt conversion to list: 0.0002021000000240747
# move input to gpu: 4.76045090000116
# calculate embeddings: 0.0015443999982380774
# add embeddings to list: 3.2486771999974735
# Embeddings for 85 of 2357 data loaders
# x_train_bt conversion to list: 0.00021940000078757294
# move input to gpu: 4.937312199999724
# calculate embeddings: 0.0007010000008449424
# add embeddings to list: 1.4668960999988485
# Embeddings for 86 of 2357 data loaders
# x_train_bt conversion to list: 0.0002440999996906612
# move input to gpu: 4.557870900000125
# calculate embeddings: 0.00082970000221394
# add embeddings to list: 4.02896779999719
# Embeddings for 87 of 2357 data loaders
# x_train_bt conversion to list: 0.00019590000010794029
# move input to gpu: 4.6790445000006
# calculate embeddings: 0.00037879999945289455
# add embeddings to list: 1.4716287000010198
# Embeddings for 88 of 2357 data loaders
# x_train_bt conversion to list: 0.000194500000361586
# move input to gpu: 4.692277300000569
# calculate embeddings: 0.000781399998231791
# add embeddings to list: 3.2716446999984328
# Embeddings for 89 of 2357 data loaders
# x_train_bt conversion to list: 0.0002057999990938697
# move input to gpu: 4.660309999999299
# calculate embeddings: 0.0007929999992484227
# add embeddings to list: 1.3435064000004786
# Embeddings for 90 of 2357 data loaders
# x_train_bt conversion to list: 0.00023879999935161322
# move input to gpu: 4.671281700000691
# calculate embeddings: 0.0009510999989288393
# add embeddings to list: 3.278303600000072
# Embeddings for 91 of 2357 data loaders
# x_train_bt conversion to list: 0.0004698999982792884
# move input to gpu: 4.719583399997646
# calculate embeddings: 0.00016450000111944973
# add embeddings to list: 3.6315028999997594
# Embeddings for 92 of 2357 data loaders
# x_train_bt conversion to list: 0.00019350000002305023
# move input to gpu: 4.683243499999662
# calculate embeddings: 0.0008928999995987397
# add embeddings to list: 3.288226399999985
# Embeddings for 93 of 2357 data loaders
# x_train_bt conversion to list: 0.0003623000011430122
# move input to gpu: 4.882553499999631
# calculate embeddings: 0.0008792000007815659
# add embeddings to list: 1.3771852999998373
# Embeddings for 94 of 2357 data loaders
# x_train_bt conversion to list: 0.00019189999875379726
# move input to gpu: 4.775325400001748
# calculate embeddings: 0.0015523999973083846
# add embeddings to list: 3.243451599999389
# Embeddings for 95 of 2357 data loaders
# x_train_bt conversion to list: 0.00019289999909233302
# move input to gpu: 4.62729980000222
# calculate embeddings: 0.00015500000154133886
# add embeddings to list: 1.4295837999998184
# Embeddings for 96 of 2357 data loaders
# x_train_bt conversion to list: 0.00021910000214120373
# move input to gpu: 4.487404299998161
# calculate embeddings: 0.0008682999978191219
# add embeddings to list: 3.2877537999993365
# Embeddings for 97 of 2357 data loaders
# x_train_bt conversion to list: 0.00022059999901102856
# move input to gpu: 7.010631999997713
# calculate embeddings: 0.00109859999793116
# add embeddings to list: 1.2965285999998741
# Embeddings for 98 of 2357 data loaders
# x_train_bt conversion to list: 0.00030450000122073106
# move input to gpu: 4.728343300001143
# calculate embeddings: 0.0018352000006416347
# add embeddings to list: 3.2981844000023557
# Embeddings for 99 of 2357 data loaders
# x_train_bt conversion to list: 0.00019389999943086877
# move input to gpu: 4.787086700001964
# calculate embeddings: 0.0005106999997224193
# add embeddings to list: 1.3642617000004975
# Embeddings for 100 of 2357 data loaders
# x_train_bt conversion to list: 0.00018700000146054663
# move input to gpu: 4.320953500002361
# calculate embeddings: 0.0008784999990893994
# add embeddings to list: 3.2878649000012956
# Embeddings for 101 of 2357 data loaders
# x_train_bt conversion to list: 0.0003065999990212731
# move input to gpu: 4.826016600000003
# calculate embeddings: 0.0011956999987887684
# add embeddings to list: 1.287932000002911
# Embeddings for 102 of 2357 data loaders
# x_train_bt conversion to list: 0.00021039999774075113
# move input to gpu: 4.92494699999952
# calculate embeddings: 0.0009922999997797888
# add embeddings to list: 3.3086726000001363
# Embeddings for 103 of 2357 data loaders
# x_train_bt conversion to list: 0.00023630000214325264
# move input to gpu: 7.084703100001207
# calculate embeddings: 0.00014849999934085645
# add embeddings to list: 1.338679599997704
# Embeddings for 104 of 2357 data loaders
# x_train_bt conversion to list: 0.00021890000061830506
# move input to gpu: 4.80225369999971
# calculate embeddings: 0.0010638000021572225
# add embeddings to list: 3.276741099998617
# Embeddings for 105 of 2357 data loaders
# x_train_bt conversion to list: 0.0002789999998640269
# move input to gpu: 4.790863100002753
# calculate embeddings: 0.0007130000012693927
# add embeddings to list: 1.3049521000029927
# Embeddings for 106 of 2357 data loaders
# x_train_bt conversion to list: 0.00019600000086938962
# move input to gpu: 4.737227599998732
# calculate embeddings: 0.0008740999983274378
# add embeddings to list: 3.2907895000025746
# Embeddings for 107 of 2357 data loaders
# x_train_bt conversion to list: 0.00019860000247717835
# move input to gpu: 4.493645999998989
# calculate embeddings: 0.0010800000018207356
# add embeddings to list: 1.2815889999983483
# Embeddings for 108 of 2357 data loaders
# x_train_bt conversion to list: 0.00021689999994123355
# move input to gpu: 4.537618900001689
# calculate embeddings: 0.0008748000000196043
# add embeddings to list: 3.29155339999852
# Embeddings for 109 of 2357 data loaders
# x_train_bt conversion to list: 0.00022149999858811498
# move input to gpu: 4.380300299999362
# calculate embeddings: 0.001003500001388602
# add embeddings to list: 3.7723393999986
# Embeddings for 110 of 2357 data loaders
# x_train_bt conversion to list: 0.00021949999791104347
# move input to gpu: 5.152030699999159
# calculate embeddings: 0.0008641999993415084
# add embeddings to list: 3.266843000001245
# Embeddings for 111 of 2357 data loaders
# x_train_bt conversion to list: 0.00038499999936902896
# move input to gpu: 5.2058257999997295
# calculate embeddings: 0.0017026999994413927
# add embeddings to list: 1.3859488999987661
# Embeddings for 112 of 2357 data loaders
# x_train_bt conversion to list: 0.00022619999799644575
# move input to gpu: 5.043096299999888
# calculate embeddings: 0.0008896999970602337
# add embeddings to list: 3.280812099998002
# Embeddings for 113 of 2357 data loaders
# x_train_bt conversion to list: 0.0002153999994334299
# move input to gpu: 4.814699399998062
# calculate embeddings: 0.000845799997478025
# add embeddings to list: 1.3568408000028285
# Embeddings for 114 of 2357 data loaders
# x_train_bt conversion to list: 0.00020170000061625615
# move input to gpu: 5.115446900003008
# calculate embeddings: 0.0008925000001909211
# add embeddings to list: 3.3191047000000253
# Embeddings for 115 of 2357 data loaders
# x_train_bt conversion to list: 0.0002359000027354341
# move input to gpu: 4.756305200000497
# calculate embeddings: 0.0007903000005171634
# add embeddings to list: 4.009813199998462
# Embeddings for 116 of 2357 data loaders
# x_train_bt conversion to list: 0.00021550000019487925
# move input to gpu: 5.220585499999288
# calculate embeddings: 0.00015239999993355013
# add embeddings to list: 3.282270799998514
# Embeddings for 117 of 2357 data loaders
# x_train_bt conversion to list: 0.00026160000197705813
# move input to gpu: 4.883548100002372
# calculate embeddings: 0.0005381999981182162
# add embeddings to list: 1.4654547999998613
# Embeddings for 118 of 2357 data loaders
# x_train_bt conversion to list: 0.00023599999985890463
# move input to gpu: 5.0608863000015845
# calculate embeddings: 0.0008598000022175256
# add embeddings to list: 3.3349789999992936
# Embeddings for 119 of 2357 data loaders
# x_train_bt conversion to list: 0.0002240999965579249
# move input to gpu: 4.948259099997813
# calculate embeddings: 0.00044010000056005083
# add embeddings to list: 1.396473500000866
# Embeddings for 120 of 2357 data loaders
# x_train_bt conversion to list: 0.00021890000061830506
# move input to gpu: 5.12330319999819
# calculate embeddings: 0.0008897000006982125
# add embeddings to list: 3.277840099999594
# Embeddings for 121 of 2357 data loaders
# x_train_bt conversion to list: 0.00019719999909284525
# move input to gpu: 5.115550599999551
# calculate embeddings: 0.00013760000001639128
# add embeddings to list: 1.416333900000609
# Embeddings for 122 of 2357 data loaders
# x_train_bt conversion to list: 0.0002592000018921681
# move input to gpu: 5.5511636000010185
# calculate embeddings: 0.0008817000016279053
# add embeddings to list: 4.4792804999997315
# Embeddings for 123 of 2357 data loaders
# x_train_bt conversion to list: 0.00026340000113123097
# move input to gpu: 5.039257999997062
# calculate embeddings: 0.001655600000958657
# add embeddings to list: 1.5685714999999618
# Embeddings for 124 of 2357 data loaders
# x_train_bt conversion to list: 0.0004637000020011328
# move input to gpu: 5.533557900002052
# calculate embeddings: 0.0008667000001878478
# add embeddings to list: 3.2914320999989286
# Embeddings for 125 of 2357 data loaders
# x_train_bt conversion to list: 0.00024980000307550654
# move input to gpu: 5.36084370000026
# calculate embeddings: 0.0004515000000537839
# add embeddings to list: 1.379281199999241
# Embeddings for 126 of 2357 data loaders
# x_train_bt conversion to list: 0.00019299999985378236
# move input to gpu: 5.050641599998926
# calculate embeddings: 0.000916299999516923
# add embeddings to list: 3.3317096999999194
# Embeddings for 127 of 2357 data loaders
# x_train_bt conversion to list: 0.00024870000197552145
# move input to gpu: 4.293770500000392
# calculate embeddings: 0.0009497999999439344
# add embeddings to list: 1.4004094999982044
# Embeddings for 128 of 2357 data loaders
# x_train_bt conversion to list: 0.00018980000095325522
# move input to gpu: 4.578556700002082
# calculate embeddings: 0.0005619000003207475
# add embeddings to list: 3.3892188999998325
# Embeddings for 129 of 2357 data loaders
# x_train_bt conversion to list: 0.0001951000012923032
# move input to gpu: 4.899049299998296
# calculate embeddings: 0.0006855999999970663
# add embeddings to list: 3.961394300000393
# Embeddings for 130 of 2357 data loaders
# x_train_bt conversion to list: 0.00022170000011101365
# move input to gpu: 4.867995900000096
# calculate embeddings: 0.0008267999983218033
# add embeddings to list: 3.2874611000006553
# Embeddings for 131 of 2357 data loaders
# x_train_bt conversion to list: 0.00026309999884688295
# move input to gpu: 4.9671167000014975
# calculate embeddings: 0.0008414000003540423
# add embeddings to list: 1.4456527000002097
# Embeddings for 132 of 2357 data loaders
# x_train_bt conversion to list: 0.00020589999985531904
# move input to gpu: 4.846629600000597
# calculate embeddings: 0.0011254999990342185
# add embeddings to list: 3.309398000001238
# Embeddings for 133 of 2357 data loaders
# x_train_bt conversion to list: 0.00027319999935571104
# move input to gpu: 4.81221960000039
# calculate embeddings: 0.0008006999996723607
# add embeddings to list: 1.3348897000032593
# Embeddings for 134 of 2357 data loaders
# x_train_bt conversion to list: 0.00020659999790950678
# move input to gpu: 4.886303700001008
# calculate embeddings: 0.0003699000008055009
# add embeddings to list: 3.33429459999752
# Embeddings for 135 of 2357 data loaders
# x_train_bt conversion to list: 0.00041480000072624534
# move input to gpu: 5.029204300000856
# calculate embeddings: 0.0009831999996094964
# add embeddings to list: 1.4258152000002156
# Embeddings for 136 of 2357 data loaders
# x_train_bt conversion to list: 0.0002272000019729603
# move input to gpu: 4.937775400001556
# calculate embeddings: 0.0009747000003699213
# add embeddings to list: 3.3153251000003365
# Embeddings for 137 of 2357 data loaders
# x_train_bt conversion to list: 0.00020809999841731042
# move input to gpu: 7.399483600001986
# calculate embeddings: 0.001799499998014653
# add embeddings to list: 1.4826587999996264
# Embeddings for 138 of 2357 data loaders
# x_train_bt conversion to list: 0.00022149999858811498
# move input to gpu: 5.108082999999169
# calculate embeddings: 0.0026341000011598226
# add embeddings to list: 3.4468602999986615
# Embeddings for 139 of 2357 data loaders
# x_train_bt conversion to list: 0.0002643000007083174
# move input to gpu: 5.36121379999895
# calculate embeddings: 0.0002907999987655785
# add embeddings to list: 1.423477799999091
# Embeddings for 140 of 2357 data loaders
# x_train_bt conversion to list: 0.00019940000129281543
# move input to gpu: 4.9849568999998155
# calculate embeddings: 0.0008786999969743192
# add embeddings to list: 3.486821799997415
# Embeddings for 141 of 2357 data loaders
# x_train_bt conversion to list: 0.0002055000004475005
# move input to gpu: 4.819556300000841
# calculate embeddings: 0.00014699999883305281
# add embeddings to list: 1.3536654999988968
# Embeddings for 142 of 2357 data loaders
# x_train_bt conversion to list: 0.00019999999858555384
# move input to gpu: 4.6808395000007295
# calculate embeddings: 0.0008863000002747867
# add embeddings to list: 3.6396015000027546
# Embeddings for 143 of 2357 data loaders
# x_train_bt conversion to list: 0.0002447000006213784
# move input to gpu: 4.5501327000019955
# calculate embeddings: 0.000785700001870282
# add embeddings to list: 1.3313706000008096
# Embeddings for 144 of 2357 data loaders
# x_train_bt conversion to list: 0.00019550000070012175
# move input to gpu: 4.844274300001416
# calculate embeddings: 0.0003848999986075796
# add embeddings to list: 3.5115657999995165
# Embeddings for 145 of 2357 data loaders
# x_train_bt conversion to list: 0.0002676999974937644
# move input to gpu: 7.313861200000247
# calculate embeddings: 0.0004794999986188486
# add embeddings to list: 1.538715399998182
# Embeddings for 146 of 2357 data loaders
# x_train_bt conversion to list: 0.00022929999977350235
# move input to gpu: 4.811258599998837
# calculate embeddings: 0.0009014000024762936
# add embeddings to list: 3.6982841999997618
# Embeddings for 147 of 2357 data loaders
# x_train_bt conversion to list: 0.0002226999968115706
# move input to gpu: 4.619781400000647
# calculate embeddings: 0.0015888999987510033
# add embeddings to list: 1.3429718999977922
# Embeddings for 148 of 2357 data loaders
# x_train_bt conversion to list: 0.00021080000078654848
# move input to gpu: 5.068854299999657
# calculate embeddings: 0.0008911000004445668
# add embeddings to list: 3.6853908999983105
# Embeddings for 149 of 2357 data loaders
# x_train_bt conversion to list: 0.00040189999708672985
# move input to gpu: 4.3210338999997475
# calculate embeddings: 0.00042440000106580555
# add embeddings to list: 1.3943622999977379
# Embeddings for 150 of 2357 data loaders
# x_train_bt conversion to list: 0.00020489999951678328
# move input to gpu: 3.3526664999990317
# calculate embeddings: 0.0007497000005969312
# add embeddings to list: 3.4853803000005428
# Embeddings for 151 of 2357 data loaders
# x_train_bt conversion to list: 0.0002372999988438096
# move input to gpu: 2.4855190999987826
# calculate embeddings: 0.0008382999985769857
# add embeddings to list: 0.717037700000219
# Embeddings for 152 of 2357 data loaders
# x_train_bt conversion to list: 0.0002351000002818182
# move input to gpu: 2.4904458000019076
# calculate embeddings: 0.000628800000413321
# add embeddings to list: 3.506334400000924
# Embeddings for 153 of 2357 data loaders
# x_train_bt conversion to list: 0.0003936000030080322
# move input to gpu: 3.6236122000009345
# calculate embeddings: 0.0009185000017168932
# add embeddings to list: 0.727297900000849
# Embeddings for 154 of 2357 data loaders
# x_train_bt conversion to list: 0.0006063000000722241
# move input to gpu: 2.435335899997881
# calculate embeddings: 0.0009153999999398366
# add embeddings to list: 3.440178000000742
# Embeddings for 155 of 2357 data loaders
# x_train_bt conversion to list: 0.00022140000146464445
# move input to gpu: 2.4222583999980998
# calculate embeddings: 0.0007905000020400621
# add embeddings to list: 0.7176348000029975
# Embeddings for 156 of 2357 data loaders
# x_train_bt conversion to list: 0.00040750000334810466
# move input to gpu: 2.4143508999986807
# calculate embeddings: 0.0006122000013419893
# add embeddings to list: 3.441295700002229
# Embeddings for 157 of 2357 data loaders
# x_train_bt conversion to list: 0.00022989999706624076
# move input to gpu: 2.410796500000288
# calculate embeddings: 0.0009325999999418855
# add embeddings to list: 0.7194038999987242
# Embeddings for 158 of 2357 data loaders
# x_train_bt conversion to list: 0.0004085000000486616
# move input to gpu: 2.432478300001094
# calculate embeddings: 0.0009937999966496136
# add embeddings to list: 3.7166054000008444
# Embeddings for 159 of 2357 data loaders
# x_train_bt conversion to list: 0.0002339000020583626
# move input to gpu: 4.364555300002394
# calculate embeddings: 0.000447300000814721
# add embeddings to list: 1.3508747999985644
# Embeddings for 160 of 2357 data loaders
# x_train_bt conversion to list: 0.00020989999757148325
# move input to gpu: 4.635328699998354
# calculate embeddings: 0.0011570999995456077
# add embeddings to list: 3.595828800000163
# Embeddings for 161 of 2357 data loaders
# x_train_bt conversion to list: 0.0002190000013797544
# move input to gpu: 4.62414500000159
# calculate embeddings: 0.0007280999998329207
# add embeddings to list: 1.4888286999994307
# Embeddings for 162 of 2357 data loaders
# x_train_bt conversion to list: 0.0003184000015608035
# move input to gpu: 7.71754719999808
# calculate embeddings: 0.0007561000020359643
# add embeddings to list: 3.5328442999998515
# Embeddings for 163 of 2357 data loaders
# x_train_bt conversion to list: 0.0002181999989261385
# move input to gpu: 4.431973000002472
# calculate embeddings: 0.0006312999976216815
# add embeddings to list: 1.5535392999991018
# Embeddings for 164 of 2357 data loaders
# x_train_bt conversion to list: 0.0002167999991797842
# move input to gpu: 4.5289169999996375
# calculate embeddings: 0.0008646999995107763
# add embeddings to list: 3.575857299998461
# Embeddings for 165 of 2357 data loaders
# x_train_bt conversion to list: 0.0004450999986147508
# move input to gpu: 4.595067400001426
# calculate embeddings: 0.0007554000003437977
# add embeddings to list: 1.5787030999999843
# Embeddings for 166 of 2357 data loaders
# x_train_bt conversion to list: 0.00033769999936339445
# move input to gpu: 4.411655199997767
# calculate embeddings: 0.0008865999989211559
# add embeddings to list: 3.575569799999357
# Embeddings for 167 of 2357 data loaders
# x_train_bt conversion to list: 0.0002330999996047467
# move input to gpu: 2.396044500001153
# calculate embeddings: 0.0012606000018422492
# add embeddings to list: 0.7617742999973416
# Embeddings for 168 of 2357 data loaders
# x_train_bt conversion to list: 0.00022279999757301994
# move input to gpu: 3.900281400001404
# calculate embeddings: 0.0009143999996013008
# add embeddings to list: 3.558638200000132
# Embeddings for 169 of 2357 data loaders
# x_train_bt conversion to list: 0.0005310999986249954
# move input to gpu: 4.3985315000027185
# calculate embeddings: 0.00014279999959398992
# add embeddings to list: 1.3684164999976929
# Embeddings for 170 of 2357 data loaders
# x_train_bt conversion to list: 0.0002669000023161061
# move input to gpu: 4.747190300000511
# calculate embeddings: 0.0008621000015409663
# add embeddings to list: 3.6072060000005877
# Embeddings for 171 of 2357 data loaders
# x_train_bt conversion to list: 0.00027739999859477393
# move input to gpu: 7.776224199998978
# calculate embeddings: 0.00014409999857889488
# add embeddings to list: 1.4340048000012757
# Embeddings for 172 of 2357 data loaders
# x_train_bt conversion to list: 0.00021850000121048652
# move input to gpu: 4.391691799999535
# calculate embeddings: 0.0006183999976201449
# add embeddings to list: 3.513118700000632
# Embeddings for 173 of 2357 data loaders
# x_train_bt conversion to list: 0.00021180000112508424
# move input to gpu: 4.116536300000007
# calculate embeddings: 0.0006743999983882532
# add embeddings to list: 1.4072864999980084
# Embeddings for 174 of 2357 data loaders
# x_train_bt conversion to list: 0.00021489999926416203
# move input to gpu: 4.596006199997646
# calculate embeddings: 0.0008727999993425328
# add embeddings to list: 3.594716100000369
# Embeddings for 175 of 2357 data loaders
# x_train_bt conversion to list: 0.00024080000002868474
# move input to gpu: 3.8475127999990946
# calculate embeddings: 0.0010151999995287042
# add embeddings to list: 0.7048323000017263
# Embeddings for 176 of 2357 data loaders
# x_train_bt conversion to list: 0.00031149999995250255
# move input to gpu: 2.4595289999997476
# calculate embeddings: 0.0008770999993430451
# add embeddings to list: 3.5463614000000234
# Embeddings for 177 of 2357 data loaders
# x_train_bt conversion to list: 0.00037090000114403665
# move input to gpu: 2.368297999997594
# calculate embeddings: 0.0007125000011001248
# add embeddings to list: 0.7088370000019495
# Embeddings for 178 of 2357 data loaders
# x_train_bt conversion to list: 0.0002356000004510861
# move input to gpu: 4.416026899998542
# calculate embeddings: 0.0008635000012873206
# add embeddings to list: 3.596830599999521
# Embeddings for 179 of 2357 data loaders
# x_train_bt conversion to list: 0.0002982000005431473
# move input to gpu: 4.832875600000989
# calculate embeddings: 0.0013225999973656144
# add embeddings to list: 1.4067764999999781
# Embeddings for 180 of 2357 data loaders
# x_train_bt conversion to list: 0.00020020000010845251
# move input to gpu: 4.597595800001727
# calculate embeddings: 0.0009080999989237171
# add embeddings to list: 3.681787700003042
# Embeddings for 181 of 2357 data loaders
# x_train_bt conversion to list: 0.000231100002565654
# move input to gpu: 3.70782600000166
# calculate embeddings: 0.0009071999993466306
# add embeddings to list: 0.7136933999972825
# Embeddings for 182 of 2357 data loaders
# x_train_bt conversion to list: 0.00021600000036414713
# move input to gpu: 2.4264838000017335
# calculate embeddings: 0.0008300999979837798
# add embeddings to list: 3.538126600000396
# Embeddings for 183 of 2357 data loaders
# x_train_bt conversion to list: 0.0002384999970672652
# move input to gpu: 2.3666029000014532
# calculate embeddings: 0.0008679999991727527
# add embeddings to list: 0.7418555000003835
# Embeddings for 184 of 2357 data loaders
# x_train_bt conversion to list: 0.0006278000000747852
# move input to gpu: 2.4131019999986165
# calculate embeddings: 0.000961900001129834
# add embeddings to list: 3.6177224999992177
# Embeddings for 185 of 2357 data loaders
# x_train_bt conversion to list: 0.0002516999993531499
# move input to gpu: 2.3375921999977436
# calculate embeddings: 0.0008692000010341872
# add embeddings to list: 0.7184185000005527
# Embeddings for 186 of 2357 data loaders
# x_train_bt conversion to list: 0.00023999999757506885
# move input to gpu: 2.45358490000217
# calculate embeddings: 0.0009135000000242144
# add embeddings to list: 3.6626122999987274
# Embeddings for 187 of 2357 data loaders
# x_train_bt conversion to list: 0.00023349999901256524
# move input to gpu: 2.37256619999971
# calculate embeddings: 0.000945200001297053
# add embeddings to list: 0.7131714999995893
# Embeddings for 188 of 2357 data loaders
# x_train_bt conversion to list: 0.00024170000324374996
# move input to gpu: 2.4802239000018744
# calculate embeddings: 0.0005687999982910696
# add embeddings to list: 3.6935248999980104
# Embeddings for 189 of 2357 data loaders
# x_train_bt conversion to list: 0.00024159999884432182
# move input to gpu: 2.4598282999977528
# calculate embeddings: 0.000869700001203455
# add embeddings to list: 0.7419350999989547
# Embeddings for 190 of 2357 data loaders
# x_train_bt conversion to list: 0.00024000000121304765
# move input to gpu: 2.431390800000372
# calculate embeddings: 0.0007334000001719687
# add embeddings to list: 3.54860429999826
# Embeddings for 191 of 2357 data loaders
# x_train_bt conversion to list: 0.00033429999893996865
# move input to gpu: 3.9968029000010574
# calculate embeddings: 0.0009171999990940094
# add embeddings to list: 0.7511639000003925
# Embeddings for 192 of 2357 data loaders
# x_train_bt conversion to list: 0.00022339999850373715
# move input to gpu: 2.3841945999993186
# calculate embeddings: 0.0009099999988393392
# add embeddings to list: 3.534786600001098
# Embeddings for 193 of 2357 data loaders
# x_train_bt conversion to list: 0.0002722000026551541
# move input to gpu: 2.4637588000005053
# calculate embeddings: 0.00012119999882997945
# add embeddings to list: 0.771138099997188
# Embeddings for 194 of 2357 data loaders
# x_train_bt conversion to list: 0.00023060000239638612
# move input to gpu: 2.499595600002067
# calculate embeddings: 0.0006168999971123412
# add embeddings to list: 3.681329700000788
# Embeddings for 195 of 2357 data loaders
# x_train_bt conversion to list: 0.00036019999970449135
# move input to gpu: 2.408235599999898
# calculate embeddings: 0.0008749000007810537
# add embeddings to list: 0.7346428000018932
# Embeddings for 196 of 2357 data loaders
# x_train_bt conversion to list: 0.00022259999968810007
# move input to gpu: 2.3924453999970865
# calculate embeddings: 0.000790699999924982
# add embeddings to list: 3.5915334000019357
# Embeddings for 197 of 2357 data loaders
# x_train_bt conversion to list: 0.00023080000028130598
# move input to gpu: 2.3124236000003293
# calculate embeddings: 0.0008374999997613486
# add embeddings to list: 0.7040473999986716
# Embeddings for 198 of 2357 data loaders
# x_train_bt conversion to list: 0.0002463000018906314
# move input to gpu: 2.3878093999992416
# calculate embeddings: 0.0009229999996023253
# add embeddings to list: 3.681573500001832
# Embeddings for 199 of 2357 data loaders
# x_train_bt conversion to list: 0.00024160000248230062
# move input to gpu: 2.2939173999984632
# calculate embeddings: 0.0007826000000932254
# add embeddings to list: 0.6887403000000631
# Embeddings for 200 of 2357 data loaders
# x_train_bt conversion to list: 0.00022949999765842222
# move input to gpu: 2.305227200002264
# calculate embeddings: 0.0009246000008715782
# add embeddings to list: 3.636225700000068
# Embeddings for 201 of 2357 data loaders
# x_train_bt conversion to list: 0.00032949999877018854
# move input to gpu: 2.2899390999991738
# calculate embeddings: 0.0006853999984741677
# add embeddings to list: 2.1280893000002834
# Embeddings for 202 of 2357 data loaders
# x_train_bt conversion to list: 0.00023670000155107118
# move input to gpu: 2.3428526999996393
# calculate embeddings: 0.0009428000012121629
# add embeddings to list: 3.5754766999998537
# Embeddings for 203 of 2357 data loaders
# x_train_bt conversion to list: 0.00023119999968912452
# move input to gpu: 2.326359099999536
# calculate embeddings: 0.0011813999990408774
# add embeddings to list: 0.7238434999999299
# Embeddings for 204 of 2357 data loaders
# x_train_bt conversion to list: 0.00024219999977503903
# move input to gpu: 2.484752299998945
# calculate embeddings: 0.00094600000011269
# add embeddings to list: 3.6326511000006576
# Embeddings for 205 of 2357 data loaders
# x_train_bt conversion to list: 0.00023850000070524402
# move input to gpu: 2.3110756000023684
# calculate embeddings: 0.0005913000022701453
# add embeddings to list: 0.7689625999992131
# Embeddings for 206 of 2357 data loaders
# x_train_bt conversion to list: 0.0004698000011558179
# move input to gpu: 2.5038368000023183
# calculate embeddings: 0.0009686000012152363
# add embeddings to list: 3.76012510000146
# Embeddings for 207 of 2357 data loaders
# x_train_bt conversion to list: 0.00023099999816622585
# move input to gpu: 4.351829300001555
# calculate embeddings: 0.0001584999990882352
# add embeddings to list: 1.363699400000769
# Embeddings for 208 of 2357 data loaders
# x_train_bt conversion to list: 0.00024050000138231553
# move input to gpu: 4.844753199999104
# calculate embeddings: 0.0007280999998329207
# add embeddings to list: 3.5648384999985865
# Embeddings for 209 of 2357 data loaders
# x_train_bt conversion to list: 0.00023119999968912452
# move input to gpu: 4.703228099999251
# calculate embeddings: 0.0004167000006418675
# add embeddings to list: 1.4402884999981325
# Embeddings for 210 of 2357 data loaders
# x_train_bt conversion to list: 0.00023080000028130598
# move input to gpu: 4.949602000000596
# calculate embeddings: 0.0008430000016232952
# add embeddings to list: 3.6417562999995425
# Embeddings for 211 of 2357 data loaders
# x_train_bt conversion to list: 0.00022499999977299012
# move input to gpu: 4.63514700000087
# calculate embeddings: 0.0006766000005882233
# add embeddings to list: 1.6183597999988706
# Embeddings for 212 of 2357 data loaders
# x_train_bt conversion to list: 0.00022000000171829015
# move input to gpu: 4.824670799996966
# calculate embeddings: 0.0009103000011236873
# add embeddings to list: 4.76624460000312
# Embeddings for 213 of 2357 data loaders
# x_train_bt conversion to list: 0.00022510000053443946
# move input to gpu: 4.81271089999791
# calculate embeddings: 0.0008194999973056838
# add embeddings to list: 1.4736312000022735
# Embeddings for 214 of 2357 data loaders
# x_train_bt conversion to list: 0.00021700000070268288
# move input to gpu: 4.225254200002382
# calculate embeddings: 0.0007418999994115438
# add embeddings to list: 4.003406200001336
# Embeddings for 215 of 2357 data loaders
# x_train_bt conversion to list: 0.0002835000013874378
# move input to gpu: 4.056697899999563
# calculate embeddings: 0.00015870000061113387
# add embeddings to list: 1.2679954000013822
# Embeddings for 216 of 2357 data loaders
# x_train_bt conversion to list: 0.0002272000019729603
# move input to gpu: 4.152860500002134
# calculate embeddings: 0.0009524999986751936
# add embeddings to list: 3.613167399998929
# Embeddings for 217 of 2357 data loaders
# x_train_bt conversion to list: 0.0002654000018083025
# move input to gpu: 4.793261200000416
# calculate embeddings: 0.0011230999989493284
# add embeddings to list: 1.4428987999999663
# Embeddings for 218 of 2357 data loaders
# x_train_bt conversion to list: 0.00033070000063162297
# move input to gpu: 4.495370900000125
# calculate embeddings: 0.0006265000010898802
# add embeddings to list: 3.645875199999864
# Embeddings for 219 of 2357 data loaders
# x_train_bt conversion to list: 0.00033289999919361435
# move input to gpu: 4.501598499999091
# calculate embeddings: 0.0001446999995096121
# add embeddings to list: 1.411301199997979
# Embeddings for 220 of 2357 data loaders
# x_train_bt conversion to list: 0.00022119999994174577
# move input to gpu: 4.358002799999667
# calculate embeddings: 0.0008458000011160038
# add embeddings to list: 3.6201279000015347
# ...
# Embeddings for 835 of 2357 data loaders
# x_train_bt conversion to list: 0.0004074000025866553
# move input to gpu: 4.2250439999988885
# calculate embeddings: 0.0007916999966255389
# add embeddings to list: 5.446661199999653
# Embeddings for 836 of 2357 data loaders
# x_train_bt conversion to list: 0.00034900000173365697
# move input to gpu: 4.366072599998006
# calculate embeddings: 0.0006382000028679613
# add embeddings to list: 7.532147300000361
# Embeddings for 837 of 2357 data loaders
# x_train_bt conversion to list: 0.0004604999994626269
# move input to gpu: 4.254851800000324
# calculate embeddings: 0.00034080000114045106
# add embeddings to list: 5.461143900000025
# Embeddings for 838 of 2357 data loaders
# x_train_bt conversion to list: 0.0003496999997878447
# move input to gpu: 4.271856399998796
# calculate embeddings: 0.0014045999996596947
# add embeddings to list: 8.431567499999801
# Embeddings for 839 of 2357 data loaders
# x_train_bt conversion to list: 0.00043200000072829425
# move input to gpu: 4.303455699999176
# calculate embeddings: 0.00015669999993406236
# add embeddings to list: 5.871186600001238
# Embeddings for 840 of 2357 data loaders
# x_train_bt conversion to list: 0.00041140000030281954
# move input to gpu: 4.1909969999978784
# calculate embeddings: 0.0006693999966955744
# add embeddings to list: 16.818588799997087
# Embeddings for 841 of 2357 data loaders
# x_train_bt conversion to list: 0.0007564000006823335
# move input to gpu: 4.00259300000107
# calculate embeddings: 0.0006485000012617093
# add embeddings to list: 6.321075799998653
# Embeddings for 842 of 2357 data loaders
# x_train_bt conversion to list: 0.000632499999483116
# move input to gpu: 4.075170199997956
# calculate embeddings: 0.0007235999983095098
# add embeddings to list: 12.72638310000184
# Embeddings for 843 of 2357 data loaders
# x_train_bt conversion to list: 0.00042630000098142773
# move input to gpu: 4.288572599998588
# calculate embeddings: 0.00033999999868683517
# add embeddings to list: 7.896885599999223
# Embeddings for 844 of 2357 data loaders
# x_train_bt conversion to list: 0.00043080000250483863
# move input to gpu: 4.779053300000669
# calculate embeddings: 0.0005755000020144507
# add embeddings to list: 11.409125199999835
# Embeddings for 845 of 2357 data loaders
# x_train_bt conversion to list: 0.00045390000013867393
# move input to gpu: 4.199965799998608
# calculate embeddings: 0.00016070000128820539
# add embeddings to list: 10.211821499997313
# Embeddings for 846 of 2357 data loaders
# x_train_bt conversion to list: 0.0004062999978486914
# move input to gpu: 4.496052800001053
# calculate embeddings: 0.0006147999993117992
# add embeddings to list: 17.829834200001642
# Embeddings for 847 of 2357 data loaders
# x_train_bt conversion to list: 0.00036040000122739
# move input to gpu: 4.54116829999839
# calculate embeddings: 0.0007446000017807819
# add embeddings to list: 3.130249300000287
# Embeddings for 848 of 2357 data loaders
# x_train_bt conversion to list: 0.0003713000005518552
# move input to gpu: 4.4066902000013215
# calculate embeddings: 0.0007016999988991302
# add embeddings to list: 3.9572565999988
# Embeddings for 849 of 2357 data loaders
# x_train_bt conversion to list: 0.0005987000004097354
# move input to gpu: 2.945842900000571
# calculate embeddings: 0.0007648999999219086
# add embeddings to list: 2.3229326000000583
# Embeddings for 850 of 2357 data loaders
# x_train_bt conversion to list: 0.00033120000080089085
# move input to gpu: 3.7893172000003688
# calculate embeddings: 0.0006376999990607146
# add embeddings to list: 4.257491500000469
# Embeddings for 851 of 2357 data loaders
# x_train_bt conversion to list: 0.00041009999767993577
# move input to gpu: 4.373316400000476
# calculate embeddings: 0.0005060000003140885
# add embeddings to list: 2.8635737000004156
# Embeddings for 852 of 2357 data loaders
# x_train_bt conversion to list: 0.0003479999977571424
# move input to gpu: 4.657773499999166
# calculate embeddings: 0.0006513999978778884
# add embeddings to list: 4.316542600001412
# Embeddings for 853 of 2357 data loaders
# x_train_bt conversion to list: 0.0008658000006107613
# move input to gpu: 4.650061000000278
# calculate embeddings: 0.00014599999849451706
# add embeddings to list: 2.873844600002485
# Embeddings for 854 of 2357 data loaders
# x_train_bt conversion to list: 0.00037119999979040585
# move input to gpu: 4.5962085999999545
# calculate embeddings: 0.0006670000002486631
# add embeddings to list: 4.258994600000733
# Embeddings for 855 of 2357 data loaders
# x_train_bt conversion to list: 0.0006915000012668315
# move input to gpu: 4.704229599999962
# calculate embeddings: 0.0008140999998431653
# add embeddings to list: 2.7971188000010443
# Embeddings for 856 of 2357 data loaders
# x_train_bt conversion to list: 0.0005955000015092082
# move input to gpu: 4.595719900000404
# calculate embeddings: 0.0007867999993322883
# add embeddings to list: 4.610069500002282
# Embeddings for 857 of 2357 data loaders
# x_train_bt conversion to list: 0.0005793000018456951
# move input to gpu: 4.634866899999906
# calculate embeddings: 0.0002860999993572477
# add embeddings to list: 2.9981068999986746
# Embeddings for 858 of 2357 data loaders
# x_train_bt conversion to list: 0.0005024999991292134
# move input to gpu: 4.483644500000082
# calculate embeddings: 0.0007638999995833728
# add embeddings to list: 4.442850399998861
# Embeddings for 859 of 2357 data loaders
# x_train_bt conversion to list: 0.0003915999986929819
# move input to gpu: 4.7117983999996795
# calculate embeddings: 0.0009930000014719553
# add embeddings to list: 2.6786724000012327
# Embeddings for 860 of 2357 data loaders
# x_train_bt conversion to list: 0.0006352999989758246
# move input to gpu: 4.583378899998934
# calculate embeddings: 0.001104399998439476
# add embeddings to list: 3.783435699999245
# Embeddings for 861 of 2357 data loaders
# x_train_bt conversion to list: 0.0003288000007160008
# move input to gpu: 2.6147146000002977
# calculate embeddings: 0.0006453999994846527
# add embeddings to list: 2.177097899999353
# Embeddings for 862 of 2357 data loaders
# x_train_bt conversion to list: 0.0005715000006603077
# move input to gpu: 2.4406886999968265
# calculate embeddings: 0.0006418999982997775
# add embeddings to list: 3.7386197000014363
# Embeddings for 863 of 2357 data loaders
# x_train_bt conversion to list: 0.0003102000009675976
# move input to gpu: 2.437243499996839
# calculate embeddings: 0.0005869000015081838
# add embeddings to list: 2.1763806999988446
# Embeddings for 864 of 2357 data loaders
# x_train_bt conversion to list: 0.0003612000000430271
# move input to gpu: 2.4244545999972615
# calculate embeddings: 0.0011785999995481689
# add embeddings to list: 3.742009199999302
# Embeddings for 865 of 2357 data loaders
# x_train_bt conversion to list: 0.0003187000002071727
# move input to gpu: 2.445006199999625
# calculate embeddings: 0.0005161999979463872
# add embeddings to list: 2.1846667999998317
# Embeddings for 866 of 2357 data loaders
# x_train_bt conversion to list: 0.0003187000002071727
# move input to gpu: 2.4190367000010156
# calculate embeddings: 0.0004623000022547785
# add embeddings to list: 3.7327528999994684
# Embeddings for 867 of 2357 data loaders
# x_train_bt conversion to list: 0.00032410000130767
# move input to gpu: 2.4003172000011546
# calculate embeddings: 0.00048469999819644727
# add embeddings to list: 2.182598200000939
# Embeddings for 868 of 2357 data loaders
# x_train_bt conversion to list: 0.00036040000122739
# move input to gpu: 2.43170789999931
# calculate embeddings: 0.0005380000002332963
# add embeddings to list: 3.7430144999998447
# Embeddings for 869 of 2357 data loaders
# x_train_bt conversion to list: 0.000506899999891175
# move input to gpu: 2.4139040000009118
# calculate embeddings: 0.0007100000002537854
# add embeddings to list: 2.164208199999848
# Embeddings for 870 of 2357 data loaders
# x_train_bt conversion to list: 0.00039649999962421134
# move input to gpu: 34.863107500001206
# calculate embeddings: 0.0006930000017746352
# add embeddings to list: 3.752909800001362
# Embeddings for 871 of 2357 data loaders
# x_train_bt conversion to list: 0.00043260000165901147
# move input to gpu: 2.407668800002284
# calculate embeddings: 0.0005958000001555774
# add embeddings to list: 2.3038889999988896
# Embeddings for 872 of 2357 data loaders
# x_train_bt conversion to list: 0.0003692999998747837
# move input to gpu: 2.409418799998093
# calculate embeddings: 0.0007048000006761868
# add embeddings to list: 3.727512800000113
# Embeddings for 873 of 2357 data loaders
# x_train_bt conversion to list: 0.00036189999809721485
# move input to gpu: 2.418586100000539
# calculate embeddings: 0.00046099999963189475
# add embeddings to list: 2.2707470999994257
# Embeddings for 874 of 2357 data loaders
# x_train_bt conversion to list: 0.0003637000008893665
# move input to gpu: 2.411769099999219
# calculate embeddings: 0.00010350000229664147
# add embeddings to list: 3.7482526999992842
# Embeddings for 875 of 2357 data loaders
# x_train_bt conversion to list: 0.0003304999991087243
# move input to gpu: 2.5148092999988876
# calculate embeddings: 0.0004716000003099907
# add embeddings to list: 2.273656099998334
# Embeddings for 876 of 2357 data loaders
# x_train_bt conversion to list: 0.0003586000020732172
# move input to gpu: 2.323022000000492
# calculate embeddings: 0.0005009000014979392
# add embeddings to list: 3.744185899999138
# Embeddings for 877 of 2357 data loaders
# x_train_bt conversion to list: 0.000530999997863546
# move input to gpu: 2.461710100000346
# calculate embeddings: 0.0005406999989645556
# add embeddings to list: 2.267669400000159
# Embeddings for 878 of 2357 data loaders
# x_train_bt conversion to list: 0.0003482000029180199
# move input to gpu: 2.282487000000401
# calculate embeddings: 0.0007155000021157321
# add embeddings to list: 3.7231223999988288
# Embeddings for 879 of 2357 data loaders
# x_train_bt conversion to list: 0.00039290000131586567
# move input to gpu: 2.3403617999974813
# calculate embeddings: 0.000609200000326382
# add embeddings to list: 2.2281686999995145
# Embeddings for 880 of 2357 data loaders
# x_train_bt conversion to list: 0.00037259999953676015
# move input to gpu: 2.260338000000047
# calculate embeddings: 0.0006499999981315341
# add embeddings to list: 3.7640711999993073
# Embeddings for 881 of 2357 data loaders
# x_train_bt conversion to list: 0.00036550000004353933
# move input to gpu: 2.4948972999991383
# calculate embeddings: 0.0004098999997950159
# add embeddings to list: 2.591403700000228
# Embeddings for 882 of 2357 data loaders
# x_train_bt conversion to list: 0.0003422999980102759
# move input to gpu: 2.244509099997231
# calculate embeddings: 0.00046379999912460335
# add embeddings to list: 3.75990720000118
# Embeddings for 883 of 2357 data loaders
# x_train_bt conversion to list: 0.0003848999986075796
# move input to gpu: 2.320261799999571
# calculate embeddings: 0.0009409999984200113
# add embeddings to list: 2.832831099996838
# Embeddings for 884 of 2357 data loaders
# x_train_bt conversion to list: 0.00038979999953880906
# move input to gpu: 2.2796204000005673
# calculate embeddings: 0.00048039999819593504
# add embeddings to list: 4.2610616000019945
# Embeddings for 885 of 2357 data loaders
# x_train_bt conversion to list: 0.00041590000182623044
# move input to gpu: 4.405388299997867
# calculate embeddings: 0.0012513999972725287
# add embeddings to list: 3.218792299998313
# Embeddings for 886 of 2357 data loaders
# x_train_bt conversion to list: 0.0003925000019080471
# move input to gpu: 4.62141690000135
# calculate embeddings: 0.00017529999968246557
# add embeddings to list: 7.7904998999983945
# Embeddings for 887 of 2357 data loaders
# x_train_bt conversion to list: 0.0005448999982036185
# move input to gpu: 4.486294700000144
# calculate embeddings: 0.0003531000002112705
# add embeddings to list: 3.402583600000071
# Embeddings for 888 of 2357 data loaders
# x_train_bt conversion to list: 0.00036159999945084564
# move input to gpu: 4.209666599999764
# calculate embeddings: 0.00014509999891743064
# add embeddings to list: 9.727733600000647
# Embeddings for 889 of 2357 data loaders
# x_train_bt conversion to list: 0.0003692999998747837
# move input to gpu: 4.972341500000766
# calculate embeddings: 0.0006331000004138332
# add embeddings to list: 3.219567600001028
# Embeddings for 890 of 2357 data loaders
# x_train_bt conversion to list: 0.000343700001394609
# move input to gpu: 4.069311299997935
# calculate embeddings: 0.001182899999548681
# add embeddings to list: 5.338721399999486
# Embeddings for 891 of 2357 data loaders
# x_train_bt conversion to list: 0.0003785999979299959
# move input to gpu: 4.689500399999815
# calculate embeddings: 0.0001548000000184402
# add embeddings to list: 3.012420999999449
# Embeddings for 892 of 2357 data loaders
# x_train_bt conversion to list: 0.0005134999992151279
# move input to gpu: 4.271378500001447
# calculate embeddings: 0.00033769999936339445
# add embeddings to list: 4.3287025000026915
# Embeddings for 893 of 2357 data loaders
# x_train_bt conversion to list: 0.00039029999970807694
# move input to gpu: 3.882550700000138
# calculate embeddings: 0.00015720000010333024
# add embeddings to list: 4.372751899998548
# Embeddings for 894 of 2357 data loaders
# x_train_bt conversion to list: 0.0003125000002910383
# move input to gpu: 3.996648500000447
# calculate embeddings: 0.0007330999978876207
# add embeddings to list: 5.6822986000006495
# Embeddings for 895 of 2357 data loaders
# x_train_bt conversion to list: 0.0003484999979264103
# move input to gpu: 4.171211399996537
# calculate embeddings: 0.0005310000015015248
# add embeddings to list: 2.91581049999877
# Embeddings for 896 of 2357 data loaders
# x_train_bt conversion to list: 0.000495000000228174
# move input to gpu: 4.394059900001594
# calculate embeddings: 0.0006522000003315043
# add embeddings to list: 4.171293899999
# Embeddings for 897 of 2357 data loaders
# x_train_bt conversion to list: 0.0005517999998119194
# move input to gpu: 4.526801100000739
# calculate embeddings: 0.005846600000950275
# add embeddings to list: 3.2632028000007267
# Embeddings for 898 of 2357 data loaders
# x_train_bt conversion to list: 0.00038470000072265975
# move input to gpu: 4.284069299999828
# calculate embeddings: 0.0007430000005115289
# add embeddings to list: 4.155535599998984
# Embeddings for 899 of 2357 data loaders
# x_train_bt conversion to list: 0.000374399998690933
# move input to gpu: 3.8029908999997133
# calculate embeddings: 0.00014419999934034422
# add embeddings to list: 5.36497700000109
# Embeddings for 900 of 2357 data loaders
# x_train_bt conversion to list: 0.0003566999985196162
# move input to gpu: 4.908209799999895
# calculate embeddings: 0.0006184999983815942
# add embeddings to list: 6.77089750000232
# Embeddings for 901 of 2357 data loaders
# x_train_bt conversion to list: 0.00044749999869964086
# move input to gpu: 3.82563410000148
# calculate embeddings: 0.00016899999900488183
# add embeddings to list: 3.876300399999309
# Embeddings for 902 of 2357 data loaders
# x_train_bt conversion to list: 0.0003485999986878596
# move input to gpu: 4.122619100002339
# calculate embeddings: 0.000993699999526143
# add embeddings to list: 4.252643800002261
# Embeddings for 903 of 2357 data loaders
# x_train_bt conversion to list: 0.00035710000156541355
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# Cell In[10], line 6
#       1 query2 = (
#       2     lazy_df.lazy().with_columns(
#       3         pl.col("processed_text").map_batches(lambda series: embedding_model.get_embeddings(series, 24576)).alias('embeddings')
#       4     )
#       5 )
# ----> 6 lazy_df = query2.collect()
#
# File f:\anaconda3\envs\mestrado\Lib\site-packages\polars\lazyframe\frame.py:1934, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, no_optimization, streaming, background, _eager)
#    1931 if background:
#    1932     return InProcessQuery(ldf.collect_concurrently())
# -> 1934 return wrap_df(ldf.collect())
#
# ComputeError: RuntimeError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
lazy_df.lazy().count().collect()

# %% [markdown]
# ## Save embeddings result to file

# %%
lazy_df.lazy().select(pl.col("id"), pl.col("embeddings")).sink_parquet('embeddings.parquet')

# %% [markdown]
# ## Calculating dataset general embedding

# %%
query3 = (
    df.lazy().select(pl.col('id'), pl.col('embeddings'))
)
df2 = query3.collect()

# %%
len(df2["embeddings"].to_numpy())
# Out:
# 675630

# %%
dataset_general_embedding = averagePooling(df2["embeddings"].to_numpy())
dataset_general_embedding
# Out:
# tensor([-3.5133e+00,  2.2863e+00, -6.7663e+00,  1.3351e+00,  4.5295e+00,
#          1.2497e+00,  7.5366e+00, -2.9391e+00,  6.2160e+00,  2.6001e+00,
#          8.0612e+00,  4.4557e+00, -8.0682e+00, -4.2549e+00,  6.9623e-01,
#         -1.1163e+01,  1.6273e+00,  1.6618e+00,  6.2046e-01,  9.1146e+00,
#         -1.4048e+00, -2.9777e+00,  2.9740e+00, -2.0703e+00, -1.6314e+00,
#         -6.1616e+00, -5.8109e+00,  5.4801e+00, -4.5849e+00,  4.4751e+00,
#          1.5677e+00, -1.1390e+02,  3.7008e+00,  5.0471e+00, -7.0308e+00,
#          1.5080e-01, -6.6176e-01,  1.8567e+00,  1.0620e+01, -4.2890e+00,
#          2.4058e+00, -4.5250e-01, -4.4988e-01,  6.4921e+00,  4.6020e+00,
#         -4.8486e+00, -8.5016e-01, -5.4629e+00,  3.4079e+00, -4.1113e+00,
#          5.4369e+00,  1.0095e+00,  5.2235e+00,  1.1085e+00, -1.8674e+01,
#          7.7118e+00,  1.6852e+01,  1.4685e+00, -2.7471e+00, -7.2529e-01,
#         -4.3492e+00, -2.3199e+00,  2.5769e+00,  5.2444e+00, -1.2436e+00,
#         -1.6418e+01,  3.4527e-01, -2.9425e+00,  2.3350e+00,  3.1240e+00,
#         -3.6361e+00,  2.2381e+00,  6.3371e+00,  9.3258e+00, -6.2786e+00,
#          2.2528e+00, -2.2229e+00,  5.4887e+00, -1.2399e+00,  6.0875e+00,
#         -6.3385e+00,  9.0543e+00, -1.2575e+00, -1.1654e+00,  4.8871e+00,
#         -2.0631e+00, -2.3438e+01,  1.6519e+00, -2.3412e+00, -2.0807e+00,
#         -7.3734e+00, -4.4896e+00, -2.1835e+00, -6.5726e+00,  5.6028e+00,
#          4.8903e+00, -1.2839e+01,  1.2678e+00, -3.8520e+00,  4.9053e+00,
#          1.3803e+00,  5.2938e+00, -2.0472e-01, -2.8350e+00, -2.7046e-01,
#         -1.4349e+00,  8.6858e+00,  4.2541e-01, -7.7084e+00, -5.3390e-01,
#          7.4230e+00,  2.0668e+00, -1.1367e+00,  2.6829e+00,  5.9348e+00,
#          9.9796e-01,  6.7489e+00,  8.9446e-01, -2.0109e+01,  3.4225e+00,
#         -3.4358e+00, -1.7708e-01, -4.6757e+00, -5.9594e+00, -3.3365e+00,
#         -2.0189e+00, -4.9937e-02, -7.7878e+00,  4.6532e+00,  6.4254e+00,
#         -6.0970e+01, -4.4196e+00, -7.8739e+00,  1.1754e+01, -6.8013e+02,
#         -7.7081e+00, -8.7749e+00, -5.4215e-03,  3.4993e+00,  5.2247e+00,
#         -1.6774e+00, -3.3375e+00,  3.3886e+00, -7.2701e+00, -1.3786e+00,
#         -6.2583e+00, -3.1715e+00,  2.1575e+00, -4.4324e+00,  6.9942e-01,
#          1.5622e+00, -1.3537e+01,  3.5142e+00, -2.3722e+00, -8.5351e+00,
#          5.2134e+00, -5.1021e+00,  5.9857e+00, -2.2685e+02, -9.2575e+00,
#         -1.3163e+01, -5.7182e+00, -1.8954e+00, -1.7222e+00, -1.2180e+01,
#          8.0111e+00, -1.1073e+01,  5.0664e+00, -2.3710e+00,  1.5819e+00,
#          1.8524e+00,  1.8632e+00,  7.5599e+00, -1.9168e+00,  3.0670e+00,
#         -2.6670e+00, -4.4080e+00, -1.4339e+00, -3.8373e+00, -1.1561e+01,
#          4.5376e+00, -4.9960e-02,  5.1219e-01,  1.8102e+00, -4.7267e+00,
#          5.3071e+00, -8.3866e+00, -2.0221e+01,  4.9117e+00, -4.9144e+00,
#         -1.9470e-02,  5.1810e+00,  4.5028e+00,  4.4493e+00, -4.6002e+00,
#          1.0184e+01,  1.0740e+01, -4.7454e+00, -8.4667e+00, -3.1473e+00,
#          3.7222e+00,  5.8085e-01, -2.1438e+00,  1.9314e+00,  4.7073e-01,
#         -5.3080e+00,  4.8337e+00, -1.6730e+00,  9.1034e+00,  2.9011e+00,
#          4.6217e+00, -5.7695e+00,  1.2194e+00,  6.9722e+00, -2.4165e+00,
#         -1.6228e+00,  1.7481e-01,  4.1713e-01, -5.7573e+00, -1.7980e+01,
#         -6.2475e+00,  7.0982e+00, -1.0276e+01, -5.4503e+00, -1.5269e+01,
#          4.1177e+00,  1.4826e+01, -4.5557e+00, -7.3502e+00, -5.6781e-01,
#          5.2879e-01, -6.7151e+00,  5.2167e+00, -9.4429e+00,  5.4121e-01,
#          2.2368e+01, -5.7242e+00, -3.0548e+00,  1.1219e+00,  7.0104e+00,
#          1.4654e+01, -5.8641e+00,  4.6168e+00,  3.7063e+00,  1.0854e+00,
#          8.5105e+00, -1.2711e+00, -6.0962e+00,  4.1045e+00, -4.3818e+00,
#          1.0832e+00,  1.2054e+01, -3.4628e+00, -1.4384e+01,  3.0081e+00,
#         -9.9628e+00,  6.5459e+00, -8.7857e+00, -7.1141e+00, -3.1097e+00,
#          6.7115e+00,  6.4638e-01,  4.5076e+00,  2.1546e+00,  1.4253e+00,
#         -8.2413e+00,  2.7140e+00,  4.2424e+00, -5.1733e+00,  2.6426e+00,
#          1.5901e+00,  2.2770e-01, -1.1967e+01,  2.3158e+00,  2.0632e+00,
#         -1.8075e+00,  1.9208e+00, -8.2453e+00, -3.9945e+00, -6.7027e+00,
#         -2.3324e+01, -1.6452e+00,  1.2150e+00, -4.7200e+00,  5.2060e+00,
#         -2.4532e+00,  5.4983e+00,  7.9503e+00, -2.5895e+00, -5.6414e+00,
#         -1.2474e+00,  2.5863e+00, -9.0786e-01,  3.6228e+00,  1.6583e+00,
#         -4.4581e+00, -9.2056e-01,  1.0951e+00, -8.0424e+00,  2.1445e+00,
#         -7.9481e-01,  4.0302e+00, -9.1413e+01,  7.6622e-01,  2.2235e+00,
#         -6.4188e+00, -2.3143e+00, -7.7526e+00, -3.2453e+00, -4.0040e+00,
#          1.2444e+01, -3.0925e+00,  3.4935e-01,  1.0742e+01, -1.3630e+00,
#          4.4597e+00, -7.0554e+00, -2.8262e+01,  5.7496e+00, -1.0937e+00,
#         -4.7565e+00,  4.7337e+00,  7.1669e+00,  5.6397e+00,  1.3973e+00,
#          5.7369e+00, -5.2746e+00,  3.6395e+00,  1.3733e-01,  1.0497e+00,
#         -3.6226e+00, -1.0440e+01,  2.3297e+00, -2.6549e+00, -1.5960e+00,
#          3.1345e+00, -1.3375e+00,  2.9731e+00, -1.4112e+00,  5.5895e+00,
#          4.1044e+00,  8.0816e+00, -3.5534e+00, -8.7236e+00,  1.9964e+00,
#          6.9743e+00,  2.9212e+00,  7.9916e+00, -3.1907e+00,  6.5036e+00,
#         -2.2245e+00, -1.1644e+01, -5.4014e-01,  6.1804e+00, -2.3503e+00,
#          3.3259e+00,  6.0368e+00, -7.3236e-01, -4.6884e+00,  7.4716e+00,
#          4.5833e+00,  1.6709e+00,  8.9899e+01, -7.8740e+00, -4.0975e+00,
#          3.6740e+00, -3.7999e+00,  4.3843e+00, -4.1947e+00,  3.3378e+00,
#         -8.6413e-02,  2.7760e+00,  1.1952e+00, -8.7465e+00,  7.5552e+00,
#         -1.4174e+00, -7.0546e+00, -3.7929e+00,  8.2617e-01, -1.0996e+01,
#          4.9050e+00, -1.4963e+00,  3.8888e+00,  1.1435e+00,  3.4028e+00,
#          2.5827e+00, -5.7593e-01,  2.0993e+00,  3.7919e+00, -8.2362e+00,
#         -4.3813e-01, -7.0356e+00, -1.1234e+00,  5.4702e+00, -3.8291e+00,
#          1.4560e+00, -2.9905e+00,  1.0972e+01,  1.2664e+00, -3.6237e+00,
#          4.3430e+00, -1.1746e+01, -6.1331e+00, -2.6551e+00, -7.6337e+00,
#         -9.2755e-01,  1.1214e+01, -6.3124e+00,  2.2362e+00,  1.0095e+01,
#         -3.0600e+00,  2.3675e+00, -1.2609e+00,  6.0625e+00, -2.1933e+00,
#          2.1412e+00,  3.9339e+00,  6.6450e+00,  3.2120e+01,  3.8472e+00,
#          1.1392e+01, -7.3828e+00, -1.8179e+00, -3.9017e-01,  1.3452e+00,
#         -2.8199e+00,  7.4559e+00,  5.1800e+00,  4.5591e+00, -9.6082e+00,
#          1.6194e+00, -5.9500e+00,  7.7819e+00,  5.2231e+00, -1.6001e+00,
#         -5.7075e+00,  4.2837e+00,  3.0018e+00, -1.1810e+00,  5.1585e+00,
#         -4.0972e+00,  1.2148e+00, -1.1977e+00, -7.2914e+00, -2.3816e+00,
#          1.6075e+00,  3.4346e+00, -5.7270e+00,  1.5868e+01, -2.7736e+00,
#         -1.3629e+01,  3.5918e+00,  1.6354e-01,  5.4251e+00, -5.4245e+00,
#          2.1504e+00,  2.0962e+00,  8.7237e+00, -1.8180e+00,  4.1556e-01,
#          5.5703e+00, -1.3888e+00,  1.6379e+00,  5.0367e-01, -1.9984e+00,
#         -5.6833e+00, -1.2158e+01,  3.3769e+00, -1.2727e+00,  3.0744e+00,
#          7.5665e+00,  8.6174e-01,  4.3775e+00, -3.0754e+00,  3.1312e+00,
#          4.2860e+00,  1.0956e+01,  2.3179e+00, -1.1179e+00, -3.8556e+00,
#          1.6138e+01,  3.4243e+00, -2.3763e+00,  5.3561e+00, -2.1318e+01,
#          2.0691e+00, -4.6208e+00,  4.5822e+01,  1.0587e-02,  2.5732e+00,
#          8.7393e-01,  7.0029e-01,  3.1362e+00,  9.0962e+00, -1.0620e+00,
#          1.9940e+01,  2.4853e+00, -7.1341e+00, -3.8602e-01,  6.5653e+00,
#          2.4059e+00,  4.6374e-01,  3.7699e+00, -4.8266e+00,  5.7455e+00,
#          4.7000e+00, -1.0596e+00,  1.2251e+00, -3.8757e+00, -5.3052e+00,
#          1.5276e+00,  7.7443e-01,  1.2141e+01,  2.7443e+00, -8.2500e+00,
#         -1.1722e+00, -4.4085e+00, -5.1210e+00, -1.5340e+00,  2.8241e+00,
#         -2.7902e+00,  9.7786e+00, -3.7889e+00,  4.2277e+00, -4.3328e+00,
#          6.7481e+00, -7.8801e+00,  3.9678e+00,  2.5621e+00, -3.9536e+00,
#          1.1472e+00,  9.6483e-01, -1.7418e+00, -2.1899e+00, -8.8407e-01,
#          1.6602e+00,  1.0678e+01, -6.8832e+00, -4.7554e+00, -3.9638e+00,
#          2.0456e+00,  1.4896e+00, -5.1085e+00, -3.3478e-01, -1.1381e+01,
#         -4.4226e+00,  4.9110e+00,  5.6118e-01, -6.9989e+00, -1.1648e+00,
#          9.8912e-01, -9.2777e-01, -1.4821e+00, -4.5284e+00,  3.2210e+00,
#         -1.6456e+00, -1.1997e+01,  3.5155e+00,  1.0463e+00,  2.1566e+00,
#         -6.0356e+00,  2.4949e-02,  6.1411e+00,  1.9236e+01, -3.3313e+00,
#         -2.5744e+00, -1.0388e+01, -2.9799e+00, -2.2729e+00,  6.1103e-01,
#         -2.1833e+00, -2.5324e+00, -5.2325e+00,  4.4295e+00, -4.6032e+00,
#         -4.0141e+00,  1.8462e+00,  5.7997e+00,  1.4386e+00, -2.8436e+01,
#          3.9102e+00, -8.6073e+00, -5.7679e+00, -1.4700e+00,  4.5748e+00,
#         -1.4409e+01,  4.9619e+00, -8.4503e+00, -3.2037e+00, -9.7799e-02,
#          1.5018e+00, -2.7020e+00, -1.2999e+00, -2.0551e+00,  1.8379e+00,
#          6.6398e-01,  5.6150e+00, -7.2297e+00, -3.2898e+00, -4.8148e+00,
#          2.4539e+00,  1.4982e+00,  2.9427e+00, -1.0171e+00,  3.1558e-02,
#          1.3950e+00,  3.2259e+00, -5.2938e+01, -4.0148e-01,  4.9545e+00,
#         -3.3215e+00,  1.6940e+00, -2.0402e-01,  2.9535e+00, -1.8397e+00,
#         -3.7676e+00,  6.6936e+00, -2.9387e+01,  3.0745e+00, -3.6386e+00,
#         -3.4573e+00,  9.2018e+00, -4.7794e+00,  6.2761e+00,  3.1244e+00,
#          2.5600e-01, -1.0468e+00,  7.8789e+00, -3.6612e+00, -1.9151e-02,
#          9.7110e+00,  1.2915e+01,  6.1009e+00,  1.0011e+01,  4.2610e+00,
#          1.2200e+00, -1.0670e-01, -1.7162e+00,  2.8029e+00, -6.8125e+00,
#          1.5985e+01, -1.0037e+00, -9.7058e+00,  2.0404e+00,  7.8983e-01,
#          2.9578e+00, -4.2226e+00,  4.4261e+00,  1.6588e+01, -1.2511e+00,
#         -2.4274e+02, -5.5559e+00, -7.8130e-01,  2.2981e+00,  2.1885e+00,
#         -6.4064e-01, -2.5577e-01,  5.2611e+01, -6.2690e+00,  5.6886e+00,
#         -5.5548e-01,  4.8203e+00,  4.6986e+00, -6.0185e+00,  6.5294e+00,
#         -4.5394e+00,  2.6263e+00, -6.4772e-01, -1.0937e+00, -6.5734e+00,
#         -6.8258e+00, -1.0561e+00,  4.5789e+00,  2.6703e+00,  1.3599e+00,
#         -2.3485e+00,  3.8380e+00, -1.0737e+00, -4.4764e+00,  3.4317e+00,
#          4.9544e+00, -7.2669e+00,  1.1948e+00,  7.7121e+00,  4.7948e+00,
#          1.0099e+01, -4.2265e+00, -4.8005e+00, -1.3292e+00, -2.3176e+00,
#          1.9675e+00,  3.2290e+00, -6.2931e-01,  8.6969e+00,  1.3875e+00,
#          1.9714e+00,  2.7131e+00, -2.1194e+00, -4.0890e-01,  8.5070e+00,
#         -6.1848e+00, -6.4142e+00,  1.6643e+00,  1.8225e+02,  5.3268e+00,
#          4.0987e+00, -9.8865e+00,  1.1137e+00, -5.9619e+00, -6.8861e+00,
#         -7.5760e+00,  4.6578e+00, -1.6825e+02, -2.1684e+00, -2.1549e+00,
#          8.6261e+00, -1.7508e+00, -4.3279e+00, -6.5958e+00, -3.1136e+00,
#         -9.4030e+00,  9.3238e+00, -5.4769e-01,  1.2721e+00,  3.7148e+00,
#         -2.0818e+01,  2.8156e+00,  7.7398e+00, -6.2175e+00, -3.0858e+00,
#          7.5635e+00,  2.1329e+00, -7.6160e-02,  1.9605e+01,  1.1115e+01,
#          2.9209e+00,  8.6465e+00,  4.4225e+00,  6.5130e-01,  3.4032e+00,
#          2.1431e+00,  7.3642e+00,  3.4859e-01, -2.4841e+00, -6.4284e+00,
#          2.0656e+00,  4.2684e+00,  9.7467e+00, -4.5833e+00,  9.9383e+00,
#         -1.6425e+00, -7.8000e+00, -6.2003e+00, -1.0046e+01,  4.5160e+00,
#         -1.2421e+00, -3.2412e+00, -4.6111e+00, -2.7113e+00,  3.1531e+00,
#         -3.3471e+00,  3.7420e+00, -7.6912e+00, -1.2006e+01,  4.2175e+00,
#          6.1844e-01,  6.2778e+00,  3.7919e+00], device='cuda:0')

# %%
dataset_ids = df2['id'].to_arrow()
print(len(dataset_ids))
# Out:
# 675630

# %% [markdown]
# ## Optimizer algorithm metaheuristic approximation

# %% [markdown]
# ### Initial metaheuristics

# %% [markdown]
# #### Random start

# %% [markdown]
# #### Greedy start

# %% [markdown]
# ### Approximation function

# %% [markdown]
# ### Optimizer algorithm

# %% [markdown]
# ## Resultant dataset approximation statistics
